# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("data.csv")
df
# Out:
#                         id             dateAdded           dateUpdated asins  \
# 0     AVpfEf_hLJeJML431ueH  2015-05-04T12:13:08Z  2018-01-29T04:38:43Z   NaN
# 1     AVpi74XfLJeJML43qZAc  2017-01-27T01:23:39Z  2018-01-03T05:21:54Z   NaN
# 2     AVpi74XfLJeJML43qZAc  2017-01-27T01:23:39Z  2018-01-03T05:21:54Z   NaN
# 3     AVpjXyCc1cnluZ0-V-Gj  2017-01-27T01:25:56Z  2018-01-04T11:52:35Z   NaN
# 4     AVphGKLPilAPnD_x1Nrm  2017-01-27T01:25:56Z  2018-01-18T03:55:18Z   NaN
# ...                    ...                   ...                   ...   ...
# 9995  AWKcCm-RHh53nbDRIh1_  2018-04-06T17:33:30Z  2018-04-06T21:02:04Z   NaN
# 9996  AWKcEq-dHh53nbDRIiES  2018-04-06T17:33:29Z  2018-04-06T21:02:04Z   NaN
# 9997  AWKb5jmLYSSHbkXwyzBA  2018-04-06T16:46:35Z  2018-04-06T21:02:01Z   NaN
# 9998  AWKcEIInYSSHbkXwy0SA  2018-04-06T17:33:30Z  2018-04-06T21:01:53Z   NaN
# 9999  AWKb6PiKYSSHbkXwyzP-  2018-04-06T16:45:52Z  2018-04-06T21:01:50Z   NaN
#
#             brand                                         categories  \
# 0     Naturalizer  Clothing,Shoes,Women's Shoes,All Women's Shoes...
# 1        MUK LUKS  Clothing,Shoes,Women's Shoes,Women's Casual Sh...
# 2        MUK LUKS  Clothing,Shoes,Women's Shoes,Women's Casual Sh...
# 3        MUK LUKS  Clothing,Shoes,Women's Shoes,All Women's Shoes...
# 4        MUK LUKS  Clothing,Shoes,Women's Shoes,All Women's Shoes...
# ...           ...                                                ...
# 9995        Asics  Women's Footwear,Women's Running Shoes,Women's...
# 9996        Asics  Women's Footwear,Women's Running Shoes,Women's...
# 9997       Kaanas  Women's Footwear,Women's Casual Boots & Shoes,...
# 9998         Nike  Women's Footwear,Women's Running Shoes,Women's...
# 9999     OTZShoes  Women's Footwear,Women's Casual Boots & Shoes,...
#
#      primaryCategories                               colors  \
# 0                Shoes       Silver,Cream Watercolor Floral
# 1                Shoes                                 Grey
# 2                Shoes                                 Grey
# 3          Shoes,Shoes                                Black
# 4                Shoes                                 Grey
# ...                ...                                  ...
# 9995             Shoes                Silver/Pistachio/Pink
# 9996             Shoes             Indigo Blue/Silver/Prune
# 9997             Shoes                                Mauve
# 9998             Shoes  Armory Blue/Armory Navy-Cirrus Blue
# 9999             Shoes                                Black
#
#                      dimension           ean  ...   prices.merchant  \
# 0                          NaN           NaN  ...     Overstock.com
# 1                          NaN  3.397705e+10  ...       Walmart.com
# 2                          NaN  3.397705e+10  ...  Slippers Dot Com
# 3     6.0 in x 6.0 in x 1.0 in  3.397705e+10  ...  Slippers Dot Com
# 4     6.0 in x 6.0 in x 1.0 in  3.397705e+10  ...       Walmart.com
# ...                        ...           ...  ...               ...
# 9995                       NaN           NaN  ...   Backcountry.com
# 9996                       NaN           NaN  ...   Backcountry.com
# 9997                       NaN           NaN  ...   Backcountry.com
# 9998                       NaN           NaN  ...   Backcountry.com
# 9999                       NaN           NaN  ...   Backcountry.com
#
#      prices.offer prices.returnPolicy                         prices.shipping  \
# 0             NaN                 NaN                                     NaN
# 1             NaN                 NaN                                Standard
# 2             NaN                 NaN                                   Value
# 3             NaN                 NaN                                   Value
# 4             NaN                 NaN                               Expedited
# ...           ...                 ...                                     ...
# 9995          25%                 NaN  Free 2-Day shipping on orders over $50
# 9996          35%                 NaN  Free 2-Day shipping on orders over $50
# 9997          50%                 NaN  Free 2-Day shipping on orders over $50
# 9998          25%                 NaN  Free 2-Day shipping on orders over $50
# 9999          50%                 NaN  Free 2-Day shipping on orders over $50
#
#      prices.size                                  prices.sourceURLs  \
# 0              S  https://www.overstock.com/Clothing-Shoes/Women...
# 1              6  https://www.walmart.com/ip/MUK-LUKS-Womens-Jan...
# 2              6  https://www.walmart.com/ip/MUK-LUKS-Womens-Jan...
# 3              6  https://www.walmart.com/ip/MUK-LUKS-Womens-Daw...
# 4              6  https://www.walmart.com/ip/MUK-LUKS-Womens-Daw...
# ...          ...                                                ...
# 9995         7.5  https://www.backcountry.com/asics-gel-foundati...
# 9996           7  https://www.backcountry.com/asics-gel-fortitud...
# 9997          11  https://www.backcountry.com/kaanas-mesa-hardwa...
# 9998         6.5  https://www.backcountry.com/nike-air-zoom-stru...
# 9999          40  https://www.backcountry.com/otzshoes-espadrill...
#
#                                                   sizes  \
# 0     6W,9W,7.5W,12W,8.5M,9N,9M,9.5M,10.5M,10W,8.5W,...
# 1                                            10,7,6,9,8
# 2                                            10,7,6,9,8
# 3                                            10,7,6,9,8
# 4                                            10,7,6,9,8
# ...                                                 ...
# 9995                            6.0,6.5,7.0,7.5,8.0,9.0
# 9996                                        6.0,6.5,7.0
# 9997                          6.0,7.0,8.0,9.0,10.0,11.0
# 9998                        6.0,6.5,7.0,7.5,8.0,8.5,9.0
# 9999                 36.0,37.0,38.0,39.0,40.0,41.0,42.0
#
#                                              sourceURLs           upc  \
# 0     https://www.walmart.com/ip/Naturalizer-Danya-W...  017136472311
# 1     https://www.walmart.com/ip/MUK-LUKS-Womens-Jan...  033977045743
# 2     https://www.walmart.com/ip/MUK-LUKS-Womens-Jan...  033977045743
# 3     https://www.walmart.com/ip/MUK-LUKS-Womens-Daw...  033977045903
# 4     https://www.walmart.com/ip/MUK-LUKS-Womens-Daw...  033977045958
# ...                                                 ...           ...
# 9995  https://www.backcountry.com/asics-gel-foundati...           NaN
# 9996  https://www.backcountry.com/asics-gel-fortitud...           NaN
# 9997  https://www.backcountry.com/kaanas-mesa-hardwa...           NaN
# 9998  https://www.backcountry.com/nike-air-zoom-stru...           NaN
# 9999  https://www.backcountry.com/otzshoes-espadrill...           NaN
#
#            weight
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 9995  1 lb 4.5 oz
# 9996          NaN
# 9997          NaN
# 9998         9 oz
# 9999          NaN
#
# [10000 rows x 34 columns]

# %% [markdown]
# #  Exploring the data

# %%
df.head()
# Out:
#                      id             dateAdded           dateUpdated asins  \
# 0  AVpfEf_hLJeJML431ueH  2015-05-04T12:13:08Z  2018-01-29T04:38:43Z   NaN
# 1  AVpi74XfLJeJML43qZAc  2017-01-27T01:23:39Z  2018-01-03T05:21:54Z   NaN
# 2  AVpi74XfLJeJML43qZAc  2017-01-27T01:23:39Z  2018-01-03T05:21:54Z   NaN
# 3  AVpjXyCc1cnluZ0-V-Gj  2017-01-27T01:25:56Z  2018-01-04T11:52:35Z   NaN
# 4  AVphGKLPilAPnD_x1Nrm  2017-01-27T01:25:56Z  2018-01-18T03:55:18Z   NaN
#
#          brand                                         categories  \
# 0  Naturalizer  Clothing,Shoes,Women's Shoes,All Women's Shoes...
# 1     MUK LUKS  Clothing,Shoes,Women's Shoes,Women's Casual Sh...
# 2     MUK LUKS  Clothing,Shoes,Women's Shoes,Women's Casual Sh...
# 3     MUK LUKS  Clothing,Shoes,Women's Shoes,All Women's Shoes...
# 4     MUK LUKS  Clothing,Shoes,Women's Shoes,All Women's Shoes...
#
#   primaryCategories                          colors                 dimension  \
# 0             Shoes  Silver,Cream Watercolor Floral                       NaN
# 1             Shoes                            Grey                       NaN
# 2             Shoes                            Grey                       NaN
# 3       Shoes,Shoes                           Black  6.0 in x 6.0 in x 1.0 in
# 4             Shoes                            Grey  6.0 in x 6.0 in x 1.0 in
#
#             ean  ...   prices.merchant prices.offer prices.returnPolicy  \
# 0           NaN  ...     Overstock.com          NaN                 NaN
# 1  3.397705e+10  ...       Walmart.com          NaN                 NaN
# 2  3.397705e+10  ...  Slippers Dot Com          NaN                 NaN
# 3  3.397705e+10  ...  Slippers Dot Com          NaN                 NaN
# 4  3.397705e+10  ...       Walmart.com          NaN                 NaN
#
#   prices.shipping prices.size  \
# 0             NaN           S
# 1        Standard           6
# 2           Value           6
# 3           Value           6
# 4       Expedited           6
#
#                                    prices.sourceURLs  \
# 0  https://www.overstock.com/Clothing-Shoes/Women...
# 1  https://www.walmart.com/ip/MUK-LUKS-Womens-Jan...
# 2  https://www.walmart.com/ip/MUK-LUKS-Womens-Jan...
# 3  https://www.walmart.com/ip/MUK-LUKS-Womens-Daw...
# 4  https://www.walmart.com/ip/MUK-LUKS-Womens-Daw...
#
#                                                sizes  \
# 0  6W,9W,7.5W,12W,8.5M,9N,9M,9.5M,10.5M,10W,8.5W,...
# 1                                         10,7,6,9,8
# 2                                         10,7,6,9,8
# 3                                         10,7,6,9,8
# 4                                         10,7,6,9,8
#
#                                           sourceURLs           upc weight
# 0  https://www.walmart.com/ip/Naturalizer-Danya-W...  017136472311    NaN
# 1  https://www.walmart.com/ip/MUK-LUKS-Womens-Jan...  033977045743    NaN
# 2  https://www.walmart.com/ip/MUK-LUKS-Womens-Jan...  033977045743    NaN
# 3  https://www.walmart.com/ip/MUK-LUKS-Womens-Daw...  033977045903    NaN
# 4  https://www.walmart.com/ip/MUK-LUKS-Womens-Daw...  033977045958    NaN
#
# [5 rows x 34 columns]

# %%
df.columns
# Out:
# Index(['id', 'dateAdded', 'dateUpdated', 'asins', 'brand', 'categories',
#        'primaryCategories', 'colors', 'dimension', 'ean', 'imageURLs', 'keys',
#        'manufacturer', 'manufacturerNumber', 'name', 'prices.amountMax',
#        'prices.amountMin', 'prices.availability', 'prices.color',
#        'prices.condition', 'prices.currency', 'prices.dateAdded',
#        'prices.dateSeen', 'prices.isSale', 'prices.merchant', 'prices.offer',
#        'prices.returnPolicy', 'prices.shipping', 'prices.size',
#        'prices.sourceURLs', 'sizes', 'sourceURLs', 'upc', 'weight'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   10000 non-null  object
#  1   dateUpdated          10000 non-null  object
#  2   brand                10000 non-null  object
#  3   categories           10000 non-null  object
#  4   primaryCategories    10000 non-null  object
#  5   imageURLs            10000 non-null  object
#  6   keys                 10000 non-null  object
#  7   manufacturerNumber   2482 non-null   object
#  8   name                 10000 non-null  object
#  9   prices.amountMax     10000 non-null  float64
#  10  prices.amountMin     10000 non-null  float64
#  11  prices.availability  434 non-null    object
#  12  prices.color         10000 non-null  object
#  13  prices.condition     438 non-null    object
#  14  prices.currency      10000 non-null  object
#  15  prices.dateSeen      10000 non-null  object
#  16  prices.isSale        10000 non-null  bool
#  17  prices.merchant      435 non-null    object
#  18  prices.offer         121 non-null    object
#  19  prices.shipping      412 non-null    object
#  20  prices.size          10000 non-null  object
#  21  prices.sourceURLs    10000 non-null  object
#  22  sizes                10000 non-null  object
#  23  sourceURLs           10000 non-null  object
#  24  upc                  9640 non-null   object
#  25  weight               299 non-null    object
# dtypes: bool(1), float64(2), object(23)
# memory usage: 1.9+ MB

# %% [markdown]
# ## Dropping the features that are not required

# %%
df.drop(["prices.dateAdded", "asins", "colors", "dimension", "manufacturer" ], axis=1,inplace=True)

# %%
corr_matrix=df.corr()

# %%
df.head()
# Out:
#                      id           dateUpdated        brand  \
# 0  AVpfEf_hLJeJML431ueH  2018-01-29T04:38:43Z  Naturalizer
# 1  AVpi74XfLJeJML43qZAc  2018-01-03T05:21:54Z     MUK LUKS
# 2  AVpi74XfLJeJML43qZAc  2018-01-03T05:21:54Z     MUK LUKS
# 3  AVpjXyCc1cnluZ0-V-Gj  2018-01-04T11:52:35Z     MUK LUKS
# 4  AVphGKLPilAPnD_x1Nrm  2018-01-18T03:55:18Z     MUK LUKS
#
#                                           categories primaryCategories  \
# 0  Clothing,Shoes,Women's Shoes,All Women's Shoes...             Shoes
# 1  Clothing,Shoes,Women's Shoes,Women's Casual Sh...             Shoes
# 2  Clothing,Shoes,Women's Shoes,Women's Casual Sh...             Shoes
# 3  Clothing,Shoes,Women's Shoes,All Women's Shoes...       Shoes,Shoes
# 4  Clothing,Shoes,Women's Shoes,All Women's Shoes...             Shoes
#
#                                            imageURLs  \
# 0  https://i5.walmartimages.com/asr/861ca6cf-fa55...
# 1  https://i5.walmartimages.com/asr/421de5d5-3a74...
# 2  https://i5.walmartimages.com/asr/421de5d5-3a74...
# 3  https://i5.walmartimages.com/asr/950d38a5-0113...
# 4  https://i5.walmartimages.com/asr/5e137bc3-c900...
#
#                                                 keys manufacturerNumber  \
# 0  naturalizer/47147sc022,017136472311,womensnatu...         47147SC022
# 1  mukluks/00173650206,033977045743,muklukswomens...       0017365020-6
# 2  mukluks/00173650206,033977045743,muklukswomens...       0017365020-6
# 3  033977045903,muklukswomensdawnsuedescuffslippe...       0017366001-6
# 4  mukluks/00173660206,033977045958,0033977045958...       0017366020-6
#
#                                                 name  prices.amountMax  ...  \
# 0  Naturalizer Danya Women N/S Open Toe Synthetic...             55.99  ...
# 1                MUK LUKS Womens Jane Suede Moccasin             47.00  ...
# 2                MUK LUKS Womens Jane Suede Moccasin             35.25  ...
# 3           MUK LUKS Womens Dawn Suede Scuff Slipper             24.75  ...
# 4           MUK LUKS Womens Dawn Suede Scuff Slipper             33.00  ...
#
#    prices.isSale   prices.merchant prices.offer prices.shipping prices.size  \
# 0          False     Overstock.com          NaN             NaN           S
# 1           True       Walmart.com          NaN        Standard           6
# 2          False  Slippers Dot Com          NaN           Value           6
# 3          False  Slippers Dot Com          NaN           Value           6
# 4           True       Walmart.com          NaN       Expedited           6
#
#                                    prices.sourceURLs  \
# 0  https://www.overstock.com/Clothing-Shoes/Women...
# 1  https://www.walmart.com/ip/MUK-LUKS-Womens-Jan...
# 2  https://www.walmart.com/ip/MUK-LUKS-Womens-Jan...
# 3  https://www.walmart.com/ip/MUK-LUKS-Womens-Daw...
# 4  https://www.walmart.com/ip/MUK-LUKS-Womens-Daw...
#
#                                                sizes  \
# 0  6W,9W,7.5W,12W,8.5M,9N,9M,9.5M,10.5M,10W,8.5W,...
# 1                                         10,7,6,9,8
# 2                                         10,7,6,9,8
# 3                                         10,7,6,9,8
# 4                                         10,7,6,9,8
#
#                                           sourceURLs           upc weight
# 0  https://www.walmart.com/ip/Naturalizer-Danya-W...  017136472311    NaN
# 1  https://www.walmart.com/ip/MUK-LUKS-Womens-Jan...  033977045743    NaN
# 2  https://www.walmart.com/ip/MUK-LUKS-Womens-Jan...  033977045743    NaN
# 3  https://www.walmart.com/ip/MUK-LUKS-Womens-Daw...  033977045903    NaN
# 4  https://www.walmart.com/ip/MUK-LUKS-Womens-Daw...  033977045958    NaN
#
# [5 rows x 26 columns]

# %%
corr_matrix
# Out:
#                   prices.amountMax  prices.amountMin  prices.isSale
# prices.amountMax          1.000000          0.699280       0.251044
# prices.amountMin          0.699280          1.000000       0.091174
# prices.isSale             0.251044          0.091174       1.000000

# %% [markdown]
# ### Plotting the correlations

# %%
df_num=df.select_dtypes(include=['int64', 'float64' ])
df_num.columns
# Out:
# Index(['prices.amountMax', 'prices.amountMin'], dtype='object')

# %%
from pandas.plotting import scatter_matrix
attributes=df_num.columns
scatter_matrix(df[attributes], figsize=(12,8))
# Out:
# array([[<AxesSubplot:xlabel='prices.amountMax', ylabel='prices.amountMax'>,
#         <AxesSubplot:xlabel='prices.amountMin', ylabel='prices.amountMax'>],
#        [<AxesSubplot:xlabel='prices.amountMax', ylabel='prices.amountMin'>,
#         <AxesSubplot:xlabel='prices.amountMin', ylabel='prices.amountMin'>]],
#       dtype=object)

# %%
df["prices.amountMax"]
# Out:
# 0        55.99
# 1        47.00
# 2        35.25
# 3        24.75
# 4        33.00
#          ...
# 9995    119.95
# 9996    119.95
# 9997    128.95
# 9998    119.95
# 9999     99.95
# Name: prices.amountMax, Length: 10000, dtype: float64

# %%
df["prices.amountMin"]
# Out:
# 0       55.99
# 1       35.25
# 2       35.25
# 3       24.75
# 4       30.39
#         ...
# 9995    89.96
# 9996    77.97
# 9997    64.47
# 9998    89.96
# 9999    49.97
# Name: prices.amountMin, Length: 10000, dtype: float64
